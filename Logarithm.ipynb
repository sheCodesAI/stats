# %% [markdown]
# <a href="https://colab.research.google.com/github/sheCodesAI/stats/blob/main/Logarithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/revenue.csv")

# %%
df
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
df.plot(x = "company", y= "revenue", kind='bar')
# Out:
# <Axes: xlabel='company'>

# %% [markdown]
# here, small bar is not proper comparable, so we use logy=True

# %%
df.plot(x = "company", y= "revenue", kind='bar', logy= True)
# Out:
# <Axes: xlabel='company'>
